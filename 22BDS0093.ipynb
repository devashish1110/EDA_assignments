# %% [markdown]
# <a href="https://colab.research.google.com/github/devashish1110/EDA_assignments/blob/main/22BDS0093.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Module 2

# %% [markdown]
# ##Importing the Dataframe

# %%
url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/Fertility2.csv"

df = pd.read_csv(url)
print(df.head())
# Out:
#    rownames morekids gender1 gender2  age afam hispanic other  work
# 0         1       no  female  female   35   no       no    no    40
# 1         2       no  female    male   33   no       no    no    52
# 2         3       no  female  female   28   no       no    no    12
# 3         4       no    male    male   28   no       no    no     0
# 4         5       no  female    male   31   no       no    no     0

# %% [markdown]
# ##Understanding the difference between append,concat, merge and join.

# %%
df1 = df.head(10)
df2 = df.head(15)
appended_df = pd.concat([df1, df2], ignore_index=True)
print(appended_df)
#This is append because it is row-wise stacking. The values are appended at the end of the first table's values.
# Out:
#     rownames morekids gender1 gender2  age afam hispanic other  work
# 0          1       no  female  female   35   no       no    no    40
# 1          2       no  female    male   33   no       no    no    52
# 2          3       no  female  female   28   no       no    no    12
# 3          4       no    male    male   28   no       no    no     0
# 4          5       no  female    male   31   no       no    no     0
# 5          6       no  female    male   33   no       no    no     0
# 6          7      yes  female  female   28   no       no    no     0
# 7          8       no  female  female   25   no       no    no    20
# 8          9      yes  female  female   31   no       no    no     0
# 9         10       no    male  female   35   no       no    no    37
# 10         1       no  female  female   35   no       no    no    40
# 11         2       no  female    male   33   no       no    no    52
# 12         3       no  female  female   28   no       no    no    12
# ...

# %%
appended_df = pd.concat([df1, df2], ignore_index=False)
print(appended_df)
#This is also append only but the indexes dont continue. The second tabel is added as is.
#ignore_index = False is by default
# Out:
#     rownames morekids gender1 gender2  age afam hispanic other  work
# 0          1       no  female  female   35   no       no    no    40
# 1          2       no  female    male   33   no       no    no    52
# 2          3       no  female  female   28   no       no    no    12
# 3          4       no    male    male   28   no       no    no     0
# 4          5       no  female    male   31   no       no    no     0
# 5          6       no  female    male   33   no       no    no     0
# 6          7      yes  female  female   28   no       no    no     0
# 7          8       no  female  female   25   no       no    no    20
# 8          9      yes  female  female   31   no       no    no     0
# 9         10       no    male  female   35   no       no    no    37
# 0          1       no  female  female   35   no       no    no    40
# 1          2       no  female    male   33   no       no    no    52
# 2          3       no  female  female   28   no       no    no    12
# ...

# %%
appended_df = pd.concat([df1,df2], axis = 0)
print(appended_df)
#axis = 0 is also by default, same as ignore_index = False.
# Out:
#     rownames morekids gender1 gender2  age afam hispanic other  work
# 0          1       no  female  female   35   no       no    no    40
# 1          2       no  female    male   33   no       no    no    52
# 2          3       no  female  female   28   no       no    no    12
# 3          4       no    male    male   28   no       no    no     0
# 4          5       no  female    male   31   no       no    no     0
# 5          6       no  female    male   33   no       no    no     0
# 6          7      yes  female  female   28   no       no    no     0
# 7          8       no  female  female   25   no       no    no    20
# 8          9      yes  female  female   31   no       no    no     0
# 9         10       no    male  female   35   no       no    no    37
# 0          1       no  female  female   35   no       no    no    40
# 1          2       no  female    male   33   no       no    no    52
# 2          3       no  female  female   28   no       no    no    12
# ...

# %%
concat_df = pd.concat([df1,df2], axis = 1,ignore_index=False)
print(concat_df)
#Now this is concatenation. Columnwise stacking
# Out:
#     rownames morekids gender1 gender2   age afam hispanic other  work  \
# 0        1.0       no  female  female  35.0   no       no    no  40.0
# 1        2.0       no  female    male  33.0   no       no    no  52.0
# 2        3.0       no  female  female  28.0   no       no    no  12.0
# 3        4.0       no    male    male  28.0   no       no    no   0.0
# 4        5.0       no  female    male  31.0   no       no    no   0.0
# 5        6.0       no  female    male  33.0   no       no    no   0.0
# 6        7.0      yes  female  female  28.0   no       no    no   0.0
# 7        8.0       no  female  female  25.0   no       no    no  20.0
# 8        9.0      yes  female  female  31.0   no       no    no   0.0
# 9       10.0       no    male  female  35.0   no       no    no  37.0
# 10       NaN      NaN     NaN     NaN   NaN  NaN      NaN   NaN   NaN
# 11       NaN      NaN     NaN     NaN   NaN  NaN      NaN   NaN   NaN
# ...

# %% [markdown]
# ## Merging

# %%
df_work = df[["rownames", "work"]]

# %%
df_work.head(10)
# Out:
#    rownames  work
# 0         1    40
# 1         2    52
# 2         3    12
# 3         4     0
# 4         5     0
# 5         6     0
# 6         7     0
# 7         8    20
# 8         9     0
# 9        10    37

# %%
df_demo = df[["rownames", "gender1", "gender2", "age"]]
df_demo.head(10)
# Out:
#    rownames gender1 gender2  age
# 0         1  female  female   35
# 1         2  female    male   33
# 2         3  female  female   28
# 3         4    male    male   28
# 4         5  female    male   31
# 5         6  female    male   33
# 6         7  female  female   28
# 7         8  female  female   25
# 8         9  female  female   31
# 9        10    male  female   35

# %%
merged = pd.merge(df_work, df_demo, on="rownames", how="inner")
print(merged.head())
# Out:
#    rownames  work gender1 gender2  age
# 0         1    40  female  female   35
# 1         2    52  female    male   33
# 2         3    12  female  female   28
# 3         4     0    male    male   28
# 4         5     0  female    male   31

# %% [markdown]
# ###Combining the Dataset

# %%
#Before combining creating the datasets
df_work = pd.DataFrame({
    "rownames": df["rownames"].head(8),
    "Work_Hours": df["work"].head(8)
})
df_age = pd.DataFrame({
    "rownames": df["rownames"].head(8),
    "Age": df["age"].head(8)
})

# %%
df_work
# Out:
#    rownames  Work_Hours
# 0         1          40
# 1         2          52
# 2         3          12
# 3         4           0
# 4         5           0
# 5         6           0
# 6         7           0
# 7         8          20

# %%
df_age
# Out:
#    rownames  Age
# 0         1   35
# 1         2   33
# 2         3   28
# 3         4   28
# 4         5   31
# 5         6   33
# 6         7   28
# 7         8   25

# %%
df_combined = pd.concat([df_work, df_age], axis=1)
print(df_combined)
# Out:
#    rownames  Work_Hours  rownames  Age
# 0         1          40         1   35
# 1         2          52         2   33
# 2         3          12         3   28
# 3         4           0         4   28
# 4         5           0         5   31
# 5         6           0         6   33
# 6         7           0         7   28
# 7         8          20         8   25

# %% [markdown]
# ###Inner Join

# %%
df_inner = df_work.merge(df_age, how = 'inner')
df_inner
#values of both work and age will appear here.
# Out:
#    rownames  Work_Hours  Age
# 0         1          40   35
# 1         2          52   33
# 2         3          12   28
# 3         4           0   28
# 4         5           0   31
# 5         6           0   33
# 6         7           0   28
# 7         8          20   25

# %% [markdown]
# ###Left Join

# %%
df_left = df_work.merge(df_age, how = 'left')
df_left
#preserves the values in the left df.
# Out:
#    rownames  Work_Hours  Age
# 0         1          40   35
# 1         2          52   33
# 2         3          12   28
# 3         4           0   28
# 4         5           0   31
# 5         6           0   33
# 6         7           0   28
# 7         8          20   25

# %% [markdown]
# ###Right Join

# %%
df_right = df_work.merge(df_age, how = 'right')
df_right
# Out:
#    rownames  Work_Hours  Age
# 0         1          40   35
# 1         2          52   33
# 2         3          12   28
# 3         4           0   28
# 4         5           0   31
# 5         6           0   33
# 6         7           0   28
# 7         8          20   25

# %% [markdown]
# ###Outer Join

# %%
df_outer = df_work.merge(df_age, how = 'outer')
df_outer
#union of both the df's.
# Out:
#    rownames  Work_Hours  Age
# 0         1          40   35
# 1         2          52   33
# 2         3          12   28
# 3         4           0   28
# 4         5           0   31
# 5         6           0   33
# 6         7           0   28
# 7         8          20   25

# %% [markdown]
# ##Reshaping and Pivoting

# %%
df_summary = df.groupby("gender1").agg({ "age": "mean",
                                        "work": "mean"
                                        }).round(2)
df_summary.columns = ["Region_A", "Region_B"]
print(df_summary)
# Out:
#          Region_A  Region_B
# gender1
# female      30.33     19.07
# male        30.38     19.34

# %%
stacked = df_summary.stack()
stacked
#stack() rotates from col to row
# Out:
# gender1
# female   Region_A    30.33
#          Region_B    19.07
# male     Region_A    30.38
#          Region_B    19.34
# dtype: float64

# %%
stacked.unstack()
#unstack() rotates from row to col
# Out:
#          Region_A  Region_B
# gender1
# female      30.33     19.07
# male        30.38     19.34

# %%
#example with another dataset
series1 = pd.Series(['aaa','bbb','ccc'], index = ["a's","b's","c's"])
series2 = pd.Series(['ddd','eee','fff'], index = ["d's","e's","f's"])
series3 = pd.Series(['ggg','hhh','iii'], index = ["g's","h's","i's"])
df_series = pd.concat([series1,series2,series3], keys = ['first','second','third'])
df_series
# Out:
# first   a's    aaa
#         b's    bbb
#         c's    ccc
# second  d's    ddd
#         e's    eee
#         f's    fff
# third   g's    ggg
#         h's    hhh
#         i's    iii
# dtype: object

# %%
df_series.unstack()
# Out:
#         a's  b's  c's  d's  e's  f's  g's  h's  i's
# first   aaa  bbb  ccc  NaN  NaN  NaN  NaN  NaN  NaN
# second  NaN  NaN  NaN  ddd  eee  fff  NaN  NaN  NaN
# third   NaN  NaN  NaN  NaN  NaN  NaN  ggg  hhh  iii

# %% [markdown]
# ##Transformation Techniques

# %% [markdown]
# ##Data Deduplication

# %%
print(df.duplicated().head(30))
df_dupes = df.head(30)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# dtype: bool

# %% [markdown]
# ####adding a few duplicates for demo

# %%
print(df_summary.shape)
print(df_summary.head())
# Out:
# (2, 2)
#          Region_A  Region_B
# gender1
# female      30.33     19.07
# male        30.38     19.34

# %%
dupes = df_dupes.sample(3, random_state=42)
dupes_df = pd.concat([df_dupes, dupes], ignore_index=True)

# %%
dupes_df.duplicated()
#values which appear for the second time will show as True
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31     True
# 32     True
# dtype: bool

# %%
print(dupes_df.duplicated().head(35))
print("Number of duplicates:", dupes_df.duplicated().sum())
#the duplicates are the last three indexes
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31     True
# 32     True
# dtype: bool
# Number of duplicates: 3

# %%
dedupe_df = dupes_df.drop_duplicates()
dedupe_df
# Out:
#     rownames morekids gender1 gender2  age afam hispanic other  work
# 0          1       no  female  female   35   no       no    no    40
# 1          2       no  female    male   33   no       no    no    52
# 2          3       no  female  female   28   no       no    no    12
# 3          4       no    male    male   28   no       no    no     0
# 4          5       no  female    male   31   no       no    no     0
# 5          6       no  female    male   33   no       no    no     0
# 6          7      yes  female  female   28   no       no    no     0
# 7          8       no  female  female   25   no       no    no    20
# 8          9      yes  female  female   31   no       no    no     0
# 9         10       no    male  female   35   no       no    no    37
# 10        11       no    male    male   34   no       no    no     0
# 11        12      yes  female  female   21   no       no    no    12
# 12        13       no  female    male   33   no       no    no    12
# ...

# %% [markdown]
# ##Replacing Values

# %%
print(df.columns)
# Out:
# Index(['rownames', 'morekids', 'gender1', 'gender2', 'age', 'afam', 'hispanic',
#        'other', 'work'],
#       dtype='object')

# %%
replaced = df.replace(to_replace={"no": "No_Kids", "yes": "Has_Kids"})
print(replaced[["rownames", "morekids"]].head(10))
# Out:
#    rownames  morekids
# 0         1   No_Kids
# 1         2   No_Kids
# 2         3   No_Kids
# 3         4   No_Kids
# 4         5   No_Kids
# 5         6   No_Kids
# 6         7  Has_Kids
# 7         8   No_Kids
# 8         9  Has_Kids
# 9        10   No_Kids

# %%
replaced = df.replace(to_replace={0: np.nan, 52: 60})
print(replaced[["rownames", "work"]].head(15))
# Out:
#     rownames  work
# 0          1  40.0
# 1          2  60.0
# 2          3  12.0
# 3          4   NaN
# 4          5   NaN
# 5          6   NaN
# 6          7   NaN
# 7          8  20.0
# 8          9   NaN
# 9         10  37.0
# 10        11   NaN
# 11        12  12.0
# 12        13  12.0
# 13        14   NaN
# 14        15  60.0

# %% [markdown]
# ##Handling Missing Data

# %%
df_miss = df.head(30)

# %%
df_miss["extra_col"] = np.nan
# Out:
# /tmp/ipython-input-2170077202.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_miss["extra_col"] = np.nan

# %%
# introduce one NaN in each row
for i in range(len(df_miss)):
    df_miss.iloc[i, i % df.shape[1]] = np.nan   # rotate through columns

# %%
df_miss["gender3"] = np.nan
# Out:
# /tmp/ipython-input-1780724648.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_miss["gender3"] = np.nan

# %%
df_miss
# Out:
#     rownames morekids gender1 gender2   age afam hispanic other  work  \
# 0        NaN       no  female  female  35.0   no       no    no  40.0
# 1        2.0      NaN  female    male  33.0   no       no    no  52.0
# 2        3.0       no     NaN  female  28.0   no       no    no  12.0
# 3        4.0       no    male     NaN  28.0   no       no    no   0.0
# 4        5.0       no  female    male   NaN   no       no    no   0.0
# 5        6.0       no  female    male  33.0  NaN       no    no   0.0
# 6        7.0      yes  female  female  28.0   no      NaN    no   0.0
# 7        8.0       no  female  female  25.0   no       no   NaN  20.0
# 8        9.0      yes  female  female  31.0   no       no    no   NaN
# 9        NaN       no    male  female  35.0   no       no    no  37.0
# 10      11.0      NaN    male    male  34.0   no       no    no   0.0
# 11      12.0      yes     NaN  female  21.0   no       no    no  12.0
# ...

# %% [markdown]
# ####Identifying null values

# %%
df_miss.isnull()
# Out:
#     rownames  morekids  gender1  gender2    age   afam  hispanic  other  \
# 0       True     False    False    False  False  False     False  False
# 1      False      True    False    False  False  False     False  False
# 2      False     False     True    False  False  False     False  False
# 3      False     False    False     True  False  False     False  False
# 4      False     False    False    False   True  False     False  False
# 5      False     False    False    False  False   True     False  False
# 6      False     False    False    False  False  False      True  False
# 7      False     False    False    False  False  False     False   True
# 8      False     False    False    False  False  False     False  False
# 9       True     False    False    False  False  False     False  False
# 10     False      True    False    False  False  False     False  False
# 11     False     False     True    False  False  False     False  False
# ...

# %%
df_miss.notnull()
# Out:
#     rownames  morekids  gender1  gender2    age   afam  hispanic  other  \
# 0      False      True     True     True   True   True      True   True
# 1       True     False     True     True   True   True      True   True
# 2       True      True    False     True   True   True      True   True
# 3       True      True     True    False   True   True      True   True
# 4       True      True     True     True  False   True      True   True
# 5       True      True     True     True   True  False      True   True
# 6       True      True     True     True   True   True     False   True
# 7       True      True     True     True   True   True      True  False
# 8       True      True     True     True   True   True      True   True
# 9      False      True     True     True   True   True      True   True
# 10      True     False     True     True   True   True      True   True
# 11      True      True    False     True   True   True      True   True
# ...

# %%
df_miss.isnull().sum()
# Out:
# rownames      4
# morekids      4
# gender1       4
# gender2       3
# age           3
# afam          3
# hispanic      3
# other         3
# work          3
# extra_col    30
# gender3      30
# dtype: int64

# %%
df_miss.isnull().sum().sum()
# Out:
# np.int64(90)

# %%
df_miss.count()
# Out:
# rownames     26
# morekids     26
# gender1      26
# gender2      27
# age          27
# afam         27
# hispanic     27
# other        27
# work         27
# extra_col     0
# gender3       0
# dtype: int64

# %%
df_miss.gender2[df.gender2.notnull()]
# Out:
# 0     female
# 1       male
# 2     female
# 4       male
# 5       male
# 6     female
# 7     female
# 8     female
# 9     female
# 10      male
# 11    female
# 13    female
# 14    female
# 15      male
# 16      male
# 17      male
# 18      male
# 19      male
# 20    female
# 22    female
# 23      male
# 24    female
# 25      male
# 26      male
# 27    female
# 28    female
# 29    female
# Name: gender2, dtype: object

# %% [markdown]
# ####Dropping Missing values

# %%
df_miss.gender1.dropna()
# Out:
# 0     female
# 1     female
# 3       male
# 4     female
# 5     female
# 6     female
# 7     female
# 8     female
# 9       male
# 10      male
# 12    female
# 13      male
# 14    female
# 15    female
# 16      male
# 17      male
# 18    female
# 19    female
# 21      male
# 22      male
# 23      male
# 24      male
# 25    female
# 26    female
# 27      male
# 28    female
# Name: gender1, dtype: object

# %%
df_miss.dropna()
# Out:
# Empty DataFrame
# Columns: [rownames, morekids, gender1, gender2, age, afam, hispanic, other, work, extra_col, gender3]
# Index: []

# %% [markdown]
# #####Dropping by Rows

# %%
df_miss.dropna(how = 'all')
# Out:
#     rownames morekids gender1 gender2   age afam hispanic other  work  \
# 0        NaN       no  female  female  35.0   no       no    no  40.0
# 1        2.0      NaN  female    male  33.0   no       no    no  52.0
# 2        3.0       no     NaN  female  28.0   no       no    no  12.0
# 3        4.0       no    male     NaN  28.0   no       no    no   0.0
# 4        5.0       no  female    male   NaN   no       no    no   0.0
# 5        6.0       no  female    male  33.0  NaN       no    no   0.0
# 6        7.0      yes  female  female  28.0   no      NaN    no   0.0
# 7        8.0       no  female  female  25.0   no       no   NaN  20.0
# 8        9.0      yes  female  female  31.0   no       no    no   NaN
# 9        NaN       no    male  female  35.0   no       no    no  37.0
# 10      11.0      NaN    male    male  34.0   no       no    no   0.0
# 11      12.0      yes     NaN  female  21.0   no       no    no  12.0
# ...

# %% [markdown]
# #####Dropping by Columns

# %%
df_miss.dropna(how='all', axis=1)
# Out:
#     rownames morekids gender1 gender2   age afam hispanic other  work
# 0        NaN       no  female  female  35.0   no       no    no  40.0
# 1        2.0      NaN  female    male  33.0   no       no    no  52.0
# 2        3.0       no     NaN  female  28.0   no       no    no  12.0
# 3        4.0       no    male     NaN  28.0   no       no    no   0.0
# 4        5.0       no  female    male   NaN   no       no    no   0.0
# 5        6.0       no  female    male  33.0  NaN       no    no   0.0
# 6        7.0      yes  female  female  28.0   no      NaN    no   0.0
# 7        8.0       no  female  female  25.0   no       no   NaN  20.0
# 8        9.0      yes  female  female  31.0   no       no    no   NaN
# 9        NaN       no    male  female  35.0   no       no    no  37.0
# 10      11.0      NaN    male    male  34.0   no       no    no   0.0
# 11      12.0      yes     NaN  female  21.0   no       no    no  12.0
# ...

# %% [markdown]
# ###Mathematical Operations with NaN

# %%
ser = df_miss.age
ser.sum()
# Out:
# np.float64(843.0)

# %%
mean_age = ser.mean()
mean_age
# Out:
# np.float64(31.22222222222222)

# %%
ser.cumsum()
# Out:
# 0      35.0
# 1      68.0
# 2      96.0
# 3     124.0
# 4       NaN
# 5     157.0
# 6     185.0
# 7     210.0
# 8     241.0
# 9     276.0
# 10    310.0
# 11    331.0
# 12    364.0
# 13      NaN
# 14    396.0
# 15    431.0
# 16    460.0
# 17    493.0
# 18    522.0
# 19    556.0
# 20    589.0
# 21    620.0
# 22      NaN
# 23    646.0
# 24    679.0
# 25    711.0
# 26    743.0
# 27    775.0
# 28    810.0
# 29    843.0
# Name: age, dtype: float64

# %% [markdown]
# ###Filling Missing values

# %%
filled = df_miss.age.fillna(mean_age)
filled
# this affects the mathematical values to be calculated. even though it is replaced with 0.
# Out:
# 0     35.000000
# 1     33.000000
# 2     28.000000
# 3     28.000000
# 4     31.222222
# 5     33.000000
# 6     28.000000
# 7     25.000000
# 8     31.000000
# 9     35.000000
# 10    34.000000
# 11    21.000000
# 12    33.000000
# 13    31.222222
# 14    32.000000
# 15    35.000000
# 16    29.000000
# 17    33.000000
# 18    29.000000
# 19    34.000000
# 20    33.000000
# 21    31.000000
# 22    31.222222
# 23    26.000000
# 24    33.000000
# 25    32.000000
# 26    32.000000
# 27    32.000000
# 28    35.000000
# 29    33.000000
# Name: age, dtype: float64

# %%
df_miss['work'] = df_miss['work'].replace(0, np.nan)
print(df_miss['work'])
# Out:
# 0     40.0
# 1     52.0
# 2     12.0
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7     20.0
# 8      NaN
# 9     37.0
# 10     NaN
# 11    12.0
# 12    12.0
# 13     NaN
# 14    52.0
# 15    52.0
# 16    52.0
# 17     NaN
# 18    20.0
# 19     NaN
# 20    44.0
# 21    50.0
# 22    50.0
# 23     NaN
# 24    20.0
# 25    12.0
# 26     NaN
# 27     NaN
# 28     NaN
# 29    52.0
# Name: work, dtype: float64
# /tmp/ipython-input-3119061161.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_miss['work'] = df_miss['work'].replace(0, np.nan)

# %%
df_miss.work.fillna(method = 'ffill')
# Out:
# /tmp/ipython-input-192059544.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_miss.work.fillna(method = 'ffill')
# 0     40.0
# 1     52.0
# 2     12.0
# 3     12.0
# 4     12.0
# 5     12.0
# 6     12.0
# 7     20.0
# 8     20.0
# 9     37.0
# 10    37.0
# 11    12.0
# 12    12.0
# 13    12.0
# 14    52.0
# 15    52.0
# 16    52.0
# 17    52.0
# 18    20.0
# 19    20.0
# 20    44.0
# 21    50.0
# 22    50.0
# 23    50.0
# 24    20.0
# 25    12.0
# 26    12.0
# 27    12.0
# 28    12.0
# 29    52.0
# Name: work, dtype: float64

# %%
df_miss.work.fillna(method = 'bfill')
# Out:
# /tmp/ipython-input-3160095744.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_miss.work.fillna(method = 'bfill')
# 0     40.0
# 1     52.0
# 2     12.0
# 3     20.0
# 4     20.0
# 5     20.0
# 6     20.0
# 7     20.0
# 8     37.0
# 9     37.0
# 10    12.0
# 11    12.0
# 12    12.0
# 13    52.0
# 14    52.0
# 15    52.0
# 16    52.0
# 17    20.0
# 18    20.0
# 19    44.0
# 20    44.0
# 21    50.0
# 22    50.0
# 23    20.0
# 24    20.0
# 25    12.0
# 26    52.0
# 27    52.0
# 28    52.0
# 29    52.0
# Name: work, dtype: float64

# %% [markdown]
# ####Interpolating missing values

# %%
ser = df_miss.work
ser.interpolate()
# Out:
# 0     40.0
# 1     52.0
# 2     12.0
# 3     13.6
# 4     15.2
# 5     16.8
# 6     18.4
# 7     20.0
# 8     28.5
# 9     37.0
# 10    24.5
# 11    12.0
# 12    12.0
# 13    32.0
# 14    52.0
# 15    52.0
# 16    52.0
# 17    36.0
# 18    20.0
# 19    32.0
# 20    44.0
# 21    50.0
# 22    50.0
# 23    35.0
# 24    20.0
# 25    12.0
# 26    22.0
# 27    32.0
# 28    42.0
# 29    52.0
# Name: work, dtype: float64

# %% [markdown]
# ####Renaming Axis Indexes

# %%
df_summary.rename(index = {"male": "M", "female": "F"})
# Out:
#          Region_A  Region_B
# gender1
# F           30.33     19.07
# M           30.38     19.34

# %%
df_summary.rename(index = str.title, columns = str.upper)
# Out:
#          REGION_A  REGION_B
# gender1
# Female      30.33     19.07
# Male        30.38     19.34

# %% [markdown]
# ##Discretizatoin and Binning

# %%
df_miss['work'] = df_miss['work'].replace(np.nan, 0)
# Out:
# /tmp/ipython-input-2033141181.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_miss['work'] = df_miss['work'].replace(np.nan, 0)

# %%
bins = [0, 20, 40, 60]
bin_labels = ['low','medium', 'high']

# %%
df_miss['work_category'] = pd.cut(df_miss['work'],bins = bins, labels=bin_labels, include_lowest=True)
df_miss
print(df_miss[['work', 'work_category']])
# Out:
#     work work_category
# 0   40.0        medium
# 1   52.0          high
# 2   12.0           low
# 3    0.0           low
# 4    0.0           low
# 5    0.0           low
# 6    0.0           low
# 7   20.0           low
# 8    0.0           low
# 9   37.0        medium
# 10   0.0           low
# 11  12.0           low
# 12  12.0           low
# 13   0.0           low
# 14  52.0          high
# 15  52.0          high
# 16  52.0          high
# 17   0.0           low
# 18  20.0           low
# 19   0.0           low
# 20  44.0          high
# 21  50.0          high
# 22  50.0          high
# 23   0.0           low
# 24  20.0           low
# 25  12.0           low
# 26   0.0           low
# 27   0.0           low
# 28   0.0           low
# 29  52.0          high
# /tmp/ipython-input-2035809978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
print(pd.value_counts(df_miss['work_category']))
# Out:
# work_category
# low       20
# high       8
# medium     2
# Name: count, dtype: int64
# /tmp/ipython-input-1882450138.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   print(pd.value_counts(df_miss['work_category']))

# %%
df_miss['work_category_auto'] = pd.cut(df_miss['work'], 5, precision=1)
print(df_miss[['work', 'work_category_auto']])
# Out:
#     work work_category_auto
# 0   40.0       (31.2, 41.6]
# 1   52.0       (41.6, 52.0]
# 2   12.0       (10.4, 20.8]
# 3    0.0      (-0.05, 10.4]
# 4    0.0      (-0.05, 10.4]
# 5    0.0      (-0.05, 10.4]
# 6    0.0      (-0.05, 10.4]
# 7   20.0       (10.4, 20.8]
# 8    0.0      (-0.05, 10.4]
# 9   37.0       (31.2, 41.6]
# 10   0.0      (-0.05, 10.4]
# 11  12.0       (10.4, 20.8]
# 12  12.0       (10.4, 20.8]
# 13   0.0      (-0.05, 10.4]
# 14  52.0       (41.6, 52.0]
# 15  52.0       (41.6, 52.0]
# 16  52.0       (41.6, 52.0]
# 17   0.0      (-0.05, 10.4]
# 18  20.0       (10.4, 20.8]
# 19   0.0      (-0.05, 10.4]
# 20  44.0       (41.6, 52.0]
# 21  50.0       (41.6, 52.0]
# 22  50.0       (41.6, 52.0]
# 23   0.0      (-0.05, 10.4]
# 24  20.0       (10.4, 20.8]
# 25  12.0       (10.4, 20.8]
# 26   0.0      (-0.05, 10.4]
# 27   0.0      (-0.05, 10.4]
# 28   0.0      (-0.05, 10.4]
# 29  52.0       (41.6, 52.0]
# /tmp/ipython-input-1956787313.py:1: SettingWithCopyWarning:
# ...

# %%
df_nonan = df_miss['work'].dropna()
df_miss.loc[df_miss['work'].notna(), 'work_category_quantile'] = pd.qcut(df_nonan, 4, duplicates='drop')
print(df_miss[['work', 'work_category_quantile']])
# Out:
#     work work_category_quantile
# 0   40.0           (12.0, 43.0]
# 1   52.0           (43.0, 52.0]
# 2   12.0         (-0.001, 12.0]
# 3    0.0         (-0.001, 12.0]
# 4    0.0         (-0.001, 12.0]
# 5    0.0         (-0.001, 12.0]
# 6    0.0         (-0.001, 12.0]
# 7   20.0           (12.0, 43.0]
# 8    0.0         (-0.001, 12.0]
# 9   37.0           (12.0, 43.0]
# 10   0.0         (-0.001, 12.0]
# 11  12.0         (-0.001, 12.0]
# 12  12.0         (-0.001, 12.0]
# 13   0.0         (-0.001, 12.0]
# 14  52.0           (43.0, 52.0]
# 15  52.0           (43.0, 52.0]
# 16  52.0           (43.0, 52.0]
# 17   0.0         (-0.001, 12.0]
# 18  20.0           (12.0, 43.0]
# 19   0.0         (-0.001, 12.0]
# 20  44.0           (43.0, 52.0]
# 21  50.0           (43.0, 52.0]
# 22  50.0           (43.0, 52.0]
# 23   0.0         (-0.001, 12.0]
# 24  20.0           (12.0, 43.0]
# 25  12.0         (-0.001, 12.0]
# 26   0.0         (-0.001, 12.0]
# 27   0.0         (-0.001, 12.0]
# ...

# %% [markdown]
# # Module 3

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/Fertility2.csv"

df = pd.read_csv(url)
print(df.head())
# Out:
#    rownames morekids gender1 gender2  age afam hispanic other  work
# 0         1       no  female  female   35   no       no    no    40
# 1         2       no  female    male   33   no       no    no    52
# 2         3       no  female  female   28   no       no    no    12
# 3         4       no    male    male   28   no       no    no     0
# 4         5       no  female    male   31   no       no    no     0

# %% [markdown]
# ## Univariate Analysis

# %%
print(df.describe())
pd.isna(df).any()
# Out:
#            rownames           age          work
# count  30000.000000  30000.000000  30000.000000
# mean   15000.500000     30.354267     19.209500
# std     8660.398374      3.383432     21.941018
# min        1.000000     21.000000      0.000000
# 25%     7500.750000     28.000000      0.000000
# 50%    15000.500000     31.000000      6.000000
# 75%    22500.250000     33.000000     45.000000
# max    30000.000000     35.000000     52.000000
# rownames    False
# morekids    False
# gender1     False
# gender2     False
# age         False
# afam        False
# hispanic    False
# other       False
# work        False
# dtype: bool

# %% [markdown]
# #### Since the data is already clean lets move on to the measures of cnetral tendency

# %%
mean = df["age"].mean()
median = df["age"].median()
mode = df["age"].mode()[0]

print("Mean:",mean,"\nMedian:", median,"\nMode : ", mode)
# Out:
# Mean: 30.354266666666668
# Median: 31.0
# Mode :  33

# %% [markdown]
#   ### Measures of Dispersion

# %%
df['age'].var()
# Out:
# 11.447610049223975

# %%
df['age'].std()
# Out:
# 3.3834316971418197

# %%
(df['age'].min(), df['age'].max())
# Out:
# (21, 35)

# %% [markdown]
# ### Quartile and IQR

# %%
quartiles = df['age'].quantile([0.25, 0.5, 0.75])
print(quartiles)
# Out:
# 0.25    28.0
# 0.50    31.0
# 0.75    33.0
# Name: age, dtype: float64

# %%
iqr = quartiles.loc[0.75] - quartiles.loc[0.25]
print(iqr)
# Out:
# 5.0

# %%
five_num = [df['age'].min(), quartiles.loc[0.25], quartiles.loc[0.5], quartiles.loc[0.75], df['age'].max()]
print(five_num)
# Out:
# [21, np.float64(28.0), np.float64(31.0), np.float64(33.0), 35]

# %%
correlation = df['age'].corr(df['work'])
print(correlation)
# Out:
# 0.1091679473239264

# %%
sns.histplot(df['age'], bins=range(int(df['age'].min()), int(df['age'].max()) + 2))
plt.title('22BDS0093 - Age Distribution Plot')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['work'], bins=15)
plt.title('22BDS0093 - Work Hours Distribution Plot')
plt.xlabel('Work Hours')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,6))
df['work'].plot(kind='density')
plt.title('22BDS0093 - Work Hours Density')
plt.xlabel('Work Hours')
plt.ylabel('Density')
plt.show()

# %%
plt.hist(df['work'], bins=15, density=True, alpha=0.5, color='RED')
plt.title('22BDS0093 - Work Hours Histogram & Density')
plt.xlabel('Work Hours')
plt.ylabel('Density')
plt.grid(True)
df['work'].plot(kind='density')
plt.show()

# %%
sns.boxplot(y=df['work'])
plt.title('22BDS0093 - Work Hours Boxplot')
plt.ylabel('Work Hours')
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.countplot(x='morekids', data=df)
plt.title('22BDS0093 - Morekids Bar Plot')
plt.xlabel('Morekids')
plt.ylabel('Count')
plt.show()

# %%
counts = df['gender1'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
plt.title('22BDS0093 - Gender1 Pie Chart')
plt.show()

# %%
#creating a contingency table
missing_values = df.isnull().sum()
table = pd.crosstab(df['gender1'], df['morekids'])

print('Missing values:', missing_values)
# Out:
# Missing values: rownames    0
# morekids    0
# gender1     0
# gender2     0
# age         0
# afam        0
# hispanic    0
# other       0
# work        0
# dtype: int64

# %%
print('Contingency table:\n', table)
# Out:
# Contingency table:
#  morekids    no   yes
# gender1
# female    9026  5523
# male      9646  5805

# %%
sns.countplot(data=df, x='gender1', hue='morekids')
plt.title('22BDS0093- Gender1 vs Morekids')
plt.xlabel('Gender1')
plt.ylabel('Count')
plt.show()

# %%
sns.scatterplot(data=df, x='age', y='work')
plt.title('22BDS0093- Age vs Work Scatter Plot')
plt.xlabel('Age')
plt.ylabel('Work Hours')

plt.show()

# %%
df_sorted = df.sort_values('age')
sns.lineplot(data=df_sorted, x='age', y='work', marker='o')
plt.title('22BDS0093 - Age vs Work ')
plt.xlabel('Age')
plt.ylabel('Work Hours')
plt.show()

# %%
corr = df[['age', 'work']].corr()
print(corr)
# Out:
#            age      work
# age   1.000000  0.109168
# work  0.109168  1.000000

# %%
sns.barplot(data=df, x='morekids', y='work')
plt.title('22BSD0093 - Morekids vs Work Hours Bar Plot')
plt.xlabel('Morekids')
plt.ylabel('Average Work Hours')
plt.show()

# %%
sns.kdeplot(data=df, x='age', hue='morekids', fill=True)
plt.title('22BDS0093 - Work Hours Density by age')
plt.xlabel('Work Hours')
plt.ylabel('Density')
plt.show()

# %%
sns.boxplot(data=df, x='gender1', y='work')
plt.title('22BDS0093 - Work Hours Boxplot by Gender1')
plt.xlabel('Gender1')
plt.ylabel('Work Hours')
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %%
df_sampled = df.sample(frac=0.10, random_state=1)
#reducing the daaset to see the visualzations clearly

sns.scatterplot(data=df_sampled, x='age', y='work', hue='morekids')
plt.title('22BDS0093 - Age vs Work Scatter Plot with Morekids (Color)')
plt.xlabel('Age')
plt.ylabel('Work Hours')
plt.show()

# %%
sns.scatterplot(data=df_sampled, x='age', y='work', hue='morekids', style='gender1')
plt.title('22BDS0093 - Age vs Work Scatter Plot with Morekids & Gender1')
plt.xlabel('Age')
plt.ylabel('Work Hours')
plt.show()

# %%
sns.scatterplot(data=df_sampled, x='age', y='work', hue='morekids', size='work', sizes=(20, 200))
plt.title('22BDS0093 - Age vs Work Bubble Plot')
plt.xlabel('Age')
plt.ylabel('Work Hours')
plt.show()

# %%
g = sns.FacetGrid(df, col='morekids')
g.map_dataframe(sns.histplot, x='work')
g.set_axis_labels('Work Hours', 'Count')
g.fig.suptitle('22BDS0093- Work Hours Histogram Faceted by Morekids', y=1.03)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_sampled = df.sample(frac=0.02, random_state=1) #using less data to make the visulaizations readable
sns.pairplot(df_sampled)
plt.show()

# %%
sns.pairplot(df_sampled, diag_kind='kde')
plt.show()

# %%
palette = {'no': 'blue', 'yes': 'orange'}  # For 'morekids' column

sns.pairplot(df_sampled, vars=['age', 'work'], hue='morekids', palette=palette)
plt.show()

# %%
sns.pairplot(df_sampled, vars=['age', 'work'], hue='gender1', palette='Set2')
plt.show()

# %% [markdown]
# #### Calculating the correlation coefficent

# %%
from scipy import stats

corr = stats.pearsonr(df['age'], df['work'])
print('p-value:\t', corr[1])
print('correlation:\t', corr[0])
# Out:
# p-value:	 3.3612072694064126e-80
# correlation:	 0.10916794732392632

# %%
correlation = df.corr(method='pearson', numeric_only=True)
print(correlation)
# Out:
#           rownames       age      work
# rownames  1.000000 -0.000623  0.002868
# age      -0.000623  1.000000  0.109168
# work      0.002868  0.109168  1.000000

# %%
correlation = df.corr(method='pearson', numeric_only=True)

sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True, cmap='coolwarm')
plt.title('22BDS0093 - Correlation Heatmap')
plt.show()

# %% [markdown]
# # Module 4

# %% [markdown]
# ## 1D Analysis

# %% [markdown]
# #### Skewness, Kurtosis, Quantiles, Frequency Distributions, 1D Plotting

# %%
num_col = "work"

mean_val = df[num_col].mean()
median_val = df[num_col].median()
mode_val = df[num_col].mode().values[0]
skewness_val = df[num_col].skew()
kurtosis_val = df[num_col].kurt()

print("Summary Statistics:")
print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Mode: {mode_val:.2f}")
print(f"Skewness: {skewness_val:.2f}")
print(f"Kurtosis: {kurtosis_val:.2f}")
# Out:
# Summary Statistics:
# Mean: 19.21
# Median: 6.00
# Mode: 0.00
# Skewness: 0.52
# Kurtosis: -1.49

# %%
plt.figure(figsize=(10, 6))
sns.distplot(df[num_col], kde=False, rug = True   )
plt.title("22BDS0093 - Skewness Plot")
plt.xlabel(num_col)
plt.ylabel("Density")
plt.show()
# Out:
# /tmp/ipython-input-3741227195.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[num_col], kde=False, rug = True   )

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(df[num_col], shade=True)
plt.title("22BDS0093 - Kurtosis Plot")
plt.xlabel(num_col)
plt.ylabel("Density")
plt.show()
# Out:
# /tmp/ipython-input-3026901655.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[num_col], shade=True)

# %%
plt.figure(figsize=(10, 6))
df[num_col].plot.hist(bins=20, edgecolor='black')
plt.title('22BDS0093 - Frequency Distribution')
plt.xlabel(num_col)
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df[num_col])
plt.title('22BDS0093 - Box Plot')
plt.xlabel(num_col)
plt.show()

# %% [markdown]
# #### Categorical Variable Analysis

# %%
plt.figure(figsize=(10, 6))
df[num_col].value_counts().plot(kind='bar')
plt.title('22BDS0093 - Bar Plot')
plt.xlabel(num_col)
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
df[num_col].plot(kind='hist', cumulative=True, bins=20, edgecolor='black')
plt.title('22BDS0093 - Cumulative Frequency Distribution')
plt.xlabel(num_col)
plt.ylabel('Cumulative Frequency')
plt.show()

# %% [markdown]
# ## 2D Analysis

# %% [markdown]
# #### Numerical vs Numerical

# %%
sns.scatterplot(data=df, x='age', y='work')
plt.title('22BDS0093 - Age vs Work Scatter Plot')
plt.xlabel('Age')
plt.ylabel('Work Hours')
plt.show()

# %%
df_sorted = df.sort_values('age')
sns.lineplot(data=df_sorted, x='age', y='work', marker='o')
plt.title('22BDS0093 - Age vs Work Line Plot')
plt.xlabel('Age')
plt.ylabel('Work Hours')
plt.show()

# %%
corr = df[['age', 'work']].corr()
print(corr)
# Out:
#            age      work
# age   1.000000  0.109168
# work  0.109168  1.000000

# %% [markdown]
# #### Numerical vs Categorical

# %%
sns.boxplot(data=df, x='gender1', y='work')
plt.title('22BDS0093 - Work Hours Boxplot by Gender1')
plt.xlabel('Gender1')
plt.ylabel('Work Hours')
plt.show()

# %%
sns.barplot(data=df, x='morekids', y='work')
plt.title('22BSD0093 - Morekids vs Work Hours Bar Plot')
plt.xlabel('Morekids')
plt.ylabel('Average Work Hours')
plt.show()

# %% [markdown]
# #### Categorical vs Categorical

# %%
sns.countplot(x='morekids', data=df)
plt.title('22BDS0093 - Morekids Bar Plot')
plt.xlabel('Morekids')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(data=df, x='gender1', hue='morekids')
plt.title('22BDS0093 - Gender1 vs Morekids')
plt.xlabel('Gender1')
plt.ylabel('Count')
plt.show()

# %%
counts = df['gender1'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
plt.title('22BDS0093 - Gender1 Pie Chart')
plt.show()

# %%
table = pd.crosstab(df['gender1'], df['morekids'])
print('Contingency table:\n', table)
# Out:
# Contingency table:
#  morekids    no   yes
# gender1
# female    9026  5523
# male      9646  5805

# %% [markdown]
# ## 3D Analysis

# %% [markdown]
# #### Multivariate/Grouped Plots

# %%
df_sampled = df.sample(frac=0.10, random_state=1)
sns.scatterplot(data=df_sampled, x='age', y='work', hue='morekids', style='gender1')
plt.title('22BDS0093 - Age vs Work Scatter Plot by Morekids & Gender1')
plt.xlabel('Age')
plt.ylabel('Work Hours')
plt.show()

# %%
palette = {'no': 'blue', 'yes': 'orange'}
sns.pairplot(df_sampled, vars=['age', 'work'], hue='morekids', palette=palette)
plt.show()

# %%
g = sns.FacetGrid(df, col='morekids')
g.map_dataframe(sns.histplot, x='work')
g.set_axis_labels('Work Hours', 'Count')
g.fig.suptitle('Work Hours Histogram Faceted by Morekids', y=1.03)
plt.show()

# %%
sns.pairplot(df_sampled, diag_kind='kde')
plt.show()

# %% [markdown]
# # Module 5

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
X = df[['age', 'work']]

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
from sklearn.cluster import KMeans

X = df[['age', 'work']]

kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X)

# %%
plt.scatter(X.values[y_kmeans == 0, 0], X.values[y_kmeans == 0, 1], s=100, c='red', label='Cluster 1')
plt.scatter(X.values[y_kmeans == 1, 0], X.values[y_kmeans == 1, 1], s=100, c='blue', label='Cluster 2')
plt.scatter(X.values[y_kmeans == 2, 0], X.values[y_kmeans == 2, 1], s=100, c='green', label='Cluster 3')
plt.scatter(X.values[y_kmeans == 3, 0], X.values[y_kmeans == 3, 1], s=100, c='cyan', label='Cluster 4')
plt.scatter(X.values[y_kmeans == 4, 0], X.values[y_kmeans == 4, 1], s=100, c='magenta', label='Cluster 5')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='yellow', label='Centroids')

plt.title('Clusters of Data Points')
plt.xlabel('Age')
plt.ylabel('Work Hours')
plt.legend()
plt.show()

# %%
X = df_sampled[['age', 'work']]
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 6))
plt.title('Dendrogram')
plt.xlabel('Data Points')
plt.ylabel('Euclidean Distances')
dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))
plt.show()
